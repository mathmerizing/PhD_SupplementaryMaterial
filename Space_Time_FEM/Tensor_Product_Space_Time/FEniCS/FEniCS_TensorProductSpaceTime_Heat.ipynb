# %%
# FEniCS for spatial FEM
try:
    import dolfin
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenics-install.sh" -O "/tmp/fenics-install.sh" && bash "/tmp/fenics-install.sh"
    import dolfin
# Out:
# 2019.1.0

# %% [markdown]
# ## Create temporal basis in SymPy

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import Mul, Id, symbols, init_printing, expand, compose, diff, lambdify, Piecewise
from IPython.display import Math, display
from fenics import IntervalMesh, Function, TestFunction, TestFunctions, FunctionSpace, dx, inner, grad, FiniteElement, MixedElement, Constant, assemble, Expression, interpolate, solve, DirichletBC, plot, errornorm, set_log_active
from ufl import replace
import time

set_log_active(False) # turn off FEniCS logging

t = symbols("t")
init_printing()

# HELPER FUNCTIONS
# compute temporal basis functions from the roots
def compute_basis_functions(roots):
    basis = []
    for i in range(len(roots)):
        f = 1 + 0*Id(t)
        for j in range(len(roots)):
            if i != j:
                f = Mul(f,(t - roots[j]) / (roots[i] - roots[j]))
        #basis.append(f)
        basis.append(expand(f))
    return basis

# transform roots from [-1, 1] to [0, 1]
def transform_roots(roots):
    new_roots = []
    for root in roots:
        new_roots.append((root + 1) / 2)
    return new_roots

# dictionary of temporal bases depending on the polynomial degree
# FE basis on reference element (0,1)
φ = {}
roots = {}

roots[0] = [1.]
φ[0] = [1 + 0*Id(t)]
roots[1] = [0., 1.]
φ[1] = [1-t, t]
roots[2] = transform_roots([-1, 0, 1])
φ[2] = compute_basis_functions(roots[2])
#roots[3] = transform_roots([-1, -sqrt(Rational(1,5)), sqrt(Rational(1,5)), 1])
#φ[3] = compute_basis_functions(roots[3])

class TimeFE:
    def __init__(self, r=1, a=0., b=1., n_time=1, n_q_points=3):
        self.r = r # polynomial degree in time
        self.n_time = n_time # number of temporal elements
        self.n_dofs = (self.r+1) * self.n_time # total number of temporal dofs on slab
        self.dof_locations = []
        self.a = a # start time of slab
        self.b = b # end time of slab
        self.k = (self.b - self.a) / self.n_time
        self.epsilon = self.k * 1e-14

        self.generate_mesh()
        self.get_full_basis()
        self.lambdify_basis()
        self.compute_quadrature(n_q_points)

    def generate_mesh(self):
        # create an uniform temporal mesh with mesh size self.k
        self.mesh = [(self.a, self.a+self.k)]
        while len(self.mesh) < self.n_time:
            self.mesh.append((self.mesh[-1][1], self.mesh[-1][1]+self.k))

    # transform basis functions from [0,1] to [a,b]
    def transform_function(self, f, a, b):
        return compose(f, (t-a)/(b-a)) # = f((t-a)/(b-a))

    # get full FE basis and its derivative on temporal mesh
    def get_full_basis(self):
        self._basis = []
        self._basis_derivative = []
        self.local_dofs = {}
        i = 0
        for (a,b) in self.mesh:
            self.local_dofs[(a,b)] = []
            for f, t_q in zip(φ[self.r], roots[self.r]):
                self._basis.append(self.transform_function(f, a, b))
                self._basis_derivative.append(diff(self._basis[-1],t))
                self.local_dofs[(a,b)].append(i)
                self.dof_locations.append(t_q*(b-a)+a)
                i += 1

    # convert SymPy functions to Python functions and ensure that they are 0 outside the element that they are defined on
    def lambdify_basis(self):
        self.phi = []
        self.dt_phi = []

        for (a,b) in self.mesh:
            for i in self.local_dofs[(a,b)]:
                self.phi.append(
                    lambdify(
                        t,
                        Piecewise(
                            (0, t < a),
                            (0, t > b),
                            (self._basis[i], True)
                        )
                    )
                )

                self.dt_phi.append(
                    lambdify(
                        t,
                        Piecewise(
                            (0, t < a),
                            (0, t > b),
                            (self._basis_derivative[i], True)
                        )
                    )
                )

    def compute_quadrature(self, n_q_points):
        # Gauss-Legendre quadrature points and weights on [-1,1]
        quad_points, quad_weights = np.polynomial.legendre.leggauss(n_q_points)

        # transform quadrature points and weights from [-1,1] to [a,b] for each temporal element [a,b]
        self.quadrature = {}
        for (a, b) in self.mesh:
            t_q = 0.5 * (b-a) * quad_points + 0.5 * (a+b)
            w_q = 0.5 * (b-a) * quad_weights
            self.quadrature[(a,b)] = [(t_q[i], w_q[i]) for i in range(t_q.shape[0])]
            
        # Gauss-Legendre quadrature points and weights on [-1,1]
        quad_points, quad_weights = np.polynomial.legendre.leggauss(n_q_points+2)

        # transform quadrature points and weights from [-1,1] to [a,b] for each temporal element [a,b]
        self.quadrature_fine = {}
        for (a, b) in self.mesh:
            t_q = 0.5 * (b-a) * quad_points + 0.5 * (a+b)
            w_q = 0.5 * (b-a) * quad_weights
            self.quadrature_fine[(a,b)] = [(t_q[i], w_q[i]) for i in range(t_q.shape[0])]

    def plot_basis(self, basis_type="function", title=None):
        assert basis_type in ["function", "derivative"], f"basis_type='{basis_type}' has not been implemented."

        _t = np.linspace(self.a, self.b, 100)
        for i in range(len(self.phi)):
            if basis_type == "function":
                plt.plot(_t, [self.phi[i](time_point) for time_point in _t], label=rf"$\varphi_{{{i}}}$")
            elif basis_type == "derivative":
                plt.plot(_t, [self.dt_phi[i](time_point) for time_point in _t], label=rf"$\partial_t \varphi_{{{i}}}$")

        plt.xlabel("t")
        plt.ylabel("f(t)")
        plt.legend()
        if title is not None:
            plt.title(title)
        plt.show()
        
    def get_solution_at_time(self, time_point, Vh):
        tmp = interpolate(Constant(0.), Vh)
        for i in range(self.n_dofs):
            tmp += Time.phi[i](time_point) * U[i]
        return tmp

# %% [markdown]
# ## Assemble space-time integrals using numerical quadrature in time and FEniCS forms in space

# %%
##############################################
# Start a time marching / time slabbing loop #
##############################################

start_time = 0.
end_time = 0.5

conv_table_start_time = time.time()
convergence_table = {}
for s in [1]: # ,2]:
    for r in [0, 1, 2]:
        convergence_table[r, s] = {}
        for slab_size in [0.5**i*0.5 for i in range(6)]: #8)]:
            for n_x in [10, 20, 40, 80, 160, 320]: # number of spatial elements in x-direction
                # start simulation
                cpu_start_time = time.time()
                print(f"CONFIG: r = {r}, slab_size = {slab_size}, n_x = {n_x}")

                slabs = [(start_time, start_time+slab_size)]
                while slabs[-1][1] < end_time - 1e-8:
                    slabs.append((slabs[-1][1], slabs[-1][1]+slab_size))

                # get spatial function space
                s = 1 # polynomial degree in space
                space_mesh = IntervalMesh(n_x, 0., 1.) # \Omega = (0,1)
                Vh = FunctionSpace(space_mesh, 'CG', s) # spatial function space for a single time point
                uh = Function(Vh)
                phih = TestFunction(Vh)

                # analytical solution
                u_analytical = Expression('sin(pi*x[0])*(1.+t)*exp(-0.5*t)', degree=2, pi=np.pi, t=0.)

                # initial condition on slab
                u0 = Function(Vh)
                u0 = interpolate(u_analytical, Vh)

                # preassemble spatial forms
                mass_form = uh*phih*dx
                laplace_form = inner(grad(uh), grad(phih))*dx

                L2_error = 0.
                total_n_dofs = 0
                total_time_n_dofs = 0

                #####################
                # Time slabbing loop:
                for k, slab in enumerate(slabs):
                    print(f"Solving on slab_{k} = Ω x ({round(slab[0],5)}, {round(slab[1],5)}) ...")

                    #########################################
                    # Create temporal finite element object #
                    #########################################
                    Time = TimeFE(r=r, a=slab[0], b=slab[1], n_time=2, n_q_points=r+1)
                    #print(Time.dof_locations)
                    #V = MixedFunctionSpace(*[Vh for _ in range(Time.n_dofs)])
                    #V = MixedFunctionSpace(*((Vh,) * Time.n_dofs))

                    element_u = FiniteElement("CG", space_mesh.ufl_cell(), s)
                    V = FunctionSpace(space_mesh, MixedElement(*[element_u for _ in range(Time.n_dofs)]))

                    U = Function(V)
                    Phi = TestFunctions(V)

                    # for visualization / debugging:
                    #Time.plot_basis(basis_type="function", title=f"Basis functions on {i}.th slab")
                    #Time.plot_basis(basis_type="derivative", title=f"Basis functions' derivatives on {i}.th slab")

                    """
                    # for debugging: verify that f(t) = t is being integrated correctly with numerical quadrature
                    integral = 0.
                    for time_element in Time.mesh:
                      print(time_element, Time.local_dofs[time_element])
                      print(Time.quadrature[time_element])
                      for (t_q, w_q) in Time.quadrature[time_element]:
                        integral += w_q * t_q
                    print(f"Numerical integral: {integral}")
                    print(f"Analytical integral: {0.5 * (slab[1]**2 - slab[0]**2)}")
                    """

                    #time_derivative = np.zeros((Time.n_dofs, Time.n_dofs))
                    #time_mass = np.zeros((Time.n_dofs, Time.n_dofs))

                    # start with "empty" space-time variational form
                    F = Constant(0.)*Phi[0]*dx
                    rhs_force = Expression('sin(pi*x[0])*exp(-0.5*t)*(0.5+pow(pi,2)+(pow(pi,2)-0.5)*t)', degree=2, pi=np.pi, t=0.)

                    # volume integrals
                    for time_element in Time.mesh:
                        for i in Time.local_dofs[time_element]:
                            for j in Time.local_dofs[time_element]:
                                for (t_q, w_q) in Time.quadrature[time_element]:
                                    #time_derivative[i, j] += w_q * Time.dt_phi[j](t_q) * Time.phi[i](t_q)
                                    #time_mass[i, j] += w_q * Time.phi[j](t_q) * Time.phi[i](t_q)

                                    F += Constant(w_q * Time.dt_phi[j](t_q) * Time.phi[i](t_q)) * replace(mass_form, {uh: U[j], phih: Phi[i]})
                                    F += Constant(w_q * Time.phi[j](t_q) * Time.phi[i](t_q)) * replace(laplace_form, {uh: U[j], phih: Phi[i]})

                    # RHS integral
                    for n, time_element in enumerate(Time.mesh):
                        for i in Time.local_dofs[time_element]:
                            # initial condition
                            if n == 0:
                                F -=  Constant(Time.phi[i](time_element[0]+Time.epsilon)) * u0 * Phi[i] * dx

                            for (t_q, w_q) in Time.quadrature[time_element]:
                                # forcing function
                                rhs_force.t = t_q
                                F -= Constant(w_q * Time.phi[i](t_q)) * rhs_force * Phi[i] * dx 


                    # jump terms (NOTE: For Gauss-Lobatto dG basis, we can hard code the values for the jump term)
                    for n, time_element in enumerate(Time.mesh):
                        # a) u_m^+ * φ_m^+
                        for i in Time.local_dofs[time_element]:
                            for j in Time.local_dofs[time_element]:
                                #time_derivative[i, j] += Time.phi[j](time_element[0]+Time.epsilon) * Time.phi[i](time_element[0]+Time.epsilon)

                                F += Constant(Time.phi[j](time_element[0]+Time.epsilon) * Time.phi[i](time_element[0]+Time.epsilon)) * replace(mass_form, {uh: U[j], phih: Phi[i]})


                        # b) u_{m-1}^- * φ_m^+
                        if n > 0:
                            prev_time_element = Time.mesh[n-1]
                            for i in Time.local_dofs[time_element]:
                                for j in Time.local_dofs[prev_time_element]:
                                    #time_derivative[i, j] += (-1.) * Time.phi[j](prev_time_element[1]-Time.epsilon) * Time.phi[i](time_element[0]+Time.epsilon)

                                    F += Constant((-1.) * Time.phi[j](prev_time_element[1]-Time.epsilon) * Time.phi[i](time_element[0]+Time.epsilon)) * replace(mass_form, {uh: U[j], phih: Phi[i]})

                    #np.set_printoptions(precision=3)
                    #print(f"time_derivative = \n{time_derivative}")
                    #print(f"time_mass = \n{time_mass}")

                    # define time dependent Dirichelt boundary conditions
                    bcs = []
                    for i, t_q in enumerate(Time.dof_locations):
                        u_analytical.t = t_q
                        if Time.n_dofs > 1:
                            bcs.append(DirichletBC(V.sub(i), u_analytical, lambda _, on_boundary: on_boundary))
                        else:
                            # for dG(0) with 1 temporal element Vh = V
                            raise NotImplementedError("Make sure that Time.n_dofs > 1, because otherwise V.sub(i) doesn't work")

                    # solve problem
                    solve(F == 0, U, bcs) #, tol=5e-6, M=Expression("exp(x[0])", degree=2)*U[0]*dx) # TODO: adapt to adaptive mesh refinement

                    # get u0 for next slab
                    #Vh_new = FunctionSpace(U.leaf_node().ufl_function_space().mesh(), 'CG', s)
                    u0 = Time.get_solution_at_time(slab[1]-Time.epsilon, Vh) #Vh_new)

                    # plot solution
                    #plot(u0, label="FEM")
                    #plt.show()
                    #u_analytical.t = slab[1]
                    #tmp = interpolate(u_analytical, Vh)
                    #plot(tmp, label="analytical")
                    #plt.legend()
                    #plt.show()

                    # prepare convergence plot
                    total_time_n_dofs += Time.n_dofs
                    total_n_dofs += Vh.dim() * Time.n_dofs 
                    for time_element in Time.mesh:
                        for (t_q, w_q) in Time.quadrature_fine[time_element]:
                            u_q_FEM = Time.get_solution_at_time(t_q, Vh)
                            u_analytical.t = slab[1]
                            u_q_analytical = interpolate(u_analytical, Vh)
                            L2_error += w_q * assemble((u_q_analytical-u_q_FEM)**2*dx)

                    print("Done.\n")



                print("------------")
                print("| RESULTS: |")
                print("------------")
                print(f"Space-time Dofs: {total_n_dofs}")
                print("L2 error:", L2_error)
                cpu_time = round(time.time() - cpu_start_time, 5)
                print(f"CPU Time: {cpu_time} s \n\n")
                convergence_table[r, s][Vh.dim(), total_time_n_dofs] = {"dofs": total_n_dofs, "error": L2_error, "time": cpu_time}
                         
print(f"\n\nTime for creating convergence table: {round(time.time() - conv_table_start_time, 5)} s")
print("Convergence table:")
for (r, s) in convergence_table.keys():
    print(f"r = {r}, s = {s}:", convergence_table[r, s])
# Out:
# CONFIG: r = 0, slab_size = 0.5, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 22
# L2 error: 0.00033390655636383903
# CPU Time: 0.8206 s
#
#
# CONFIG: r = 0, slab_size = 0.5, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 42
# L2 error: 0.0003409845481767041
# CPU Time: 0.02575 s
#
#
# CONFIG: r = 0, slab_size = 0.5, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 82
# L2 error: 0.0003428039419131531
# CPU Time: 0.01824 s
#
#
# CONFIG: r = 0, slab_size = 0.5, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 162
# L2 error: 0.0003432619462392867
# CPU Time: 0.01997 s
#
#
# CONFIG: r = 0, slab_size = 0.5, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 322
# L2 error: 0.0003433766451531571
# CPU Time: 0.0205 s
#
#
# CONFIG: r = 0, slab_size = 0.5, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 642
# L2 error: 0.0003434053322668758
# CPU Time: 0.02141 s
#
#
# CONFIG: r = 0, slab_size = 0.25, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 44
# L2 error: 0.00013769555287012966
# CPU Time: 0.81223 s
#
#
# CONFIG: r = 0, slab_size = 0.25, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 84
# L2 error: 0.00014112438411104913
# CPU Time: 0.03677 s
#
#
# CONFIG: r = 0, slab_size = 0.25, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 164
# L2 error: 0.00014200987472015104
# CPU Time: 0.03596 s
#
#
# CONFIG: r = 0, slab_size = 0.25, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 324
# L2 error: 0.0001422330422988204
# CPU Time: 0.03698 s
#
#
# CONFIG: r = 0, slab_size = 0.25, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 644
# L2 error: 0.00014228894681263363
# CPU Time: 0.04055 s
#
#
# CONFIG: r = 0, slab_size = 0.25, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1284
# L2 error: 0.00014230292996410916
# CPU Time: 0.04036 s
#
#
# CONFIG: r = 0, slab_size = 0.125, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 88
# L2 error: 4.5500780357867194e-05
# CPU Time: 0.0731 s
#
#
# CONFIG: r = 0, slab_size = 0.125, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 168
# L2 error: 4.697159860075206e-05
# CPU Time: 0.08292 s
#
#
# CONFIG: r = 0, slab_size = 0.125, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 328
# L2 error: 4.7354895906895804e-05
# CPU Time: 0.07384 s
#
#
# CONFIG: r = 0, slab_size = 0.125, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 648
# L2 error: 4.7451716467778596e-05
# CPU Time: 0.07134 s
#
#
# CONFIG: r = 0, slab_size = 0.125, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1288
# L2 error: 4.7475984221840064e-05
# CPU Time: 0.07825 s
#
#
# CONFIG: r = 0, slab_size = 0.125, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2568
# L2 error: 4.748205507575802e-05
# CPU Time: 0.08703 s
#
#
# CONFIG: r = 0, slab_size = 0.0625, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 176
# L2 error: 1.3166249344691164e-05
# CPU Time: 0.14008 s
#
#
# CONFIG: r = 0, slab_size = 0.0625, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 336
# L2 error: 1.379242992442329e-05
# CPU Time: 0.16539 s
#
#
# CONFIG: r = 0, slab_size = 0.0625, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 656
# L2 error: 1.3958002037805872e-05
# CPU Time: 0.17141 s
#
#
# CONFIG: r = 0, slab_size = 0.0625, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1296
# L2 error: 1.3999978037426572e-05
# CPU Time: 0.14107 s
#
#
# CONFIG: r = 0, slab_size = 0.0625, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2576
# L2 error: 1.4010508772651705e-05
# CPU Time: 0.15418 s
#
#
# CONFIG: r = 0, slab_size = 0.0625, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 5136
# L2 error: 1.4013143760363671e-05
# CPU Time: 0.16373 s
#
#
# CONFIG: r = 0, slab_size = 0.03125, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 352
# L2 error: 3.463580623903075e-06
# CPU Time: 0.27905 s
#
#
# CONFIG: r = 0, slab_size = 0.03125, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 672
# L2 error: 3.737517416771923e-06
# CPU Time: 0.28315 s
#
#
# CONFIG: r = 0, slab_size = 0.03125, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1312
# L2 error: 3.811704144555984e-06
# CPU Time: 0.27779 s
#
#
# CONFIG: r = 0, slab_size = 0.03125, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2592
# L2 error: 3.830624514753964e-06
# CPU Time: 0.29935 s
#
#
# CONFIG: r = 0, slab_size = 0.03125, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 5152
# L2 error: 3.835378239020071e-06
# CPU Time: 0.29952 s
#
#
# CONFIG: r = 0, slab_size = 0.03125, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 10272
# L2 error: 3.836568155209206e-06
# CPU Time: 0.32482 s
#
#
# CONFIG: r = 0, slab_size = 0.015625, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 704
# L2 error: 8.386581900102804e-07
# CPU Time: 0.56513 s
#
#
# CONFIG: r = 0, slab_size = 0.015625, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1344
# L2 error: 9.600541851731846e-07
# CPU Time: 0.69983 s
#
#
# CONFIG: r = 0, slab_size = 0.015625, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2624
# L2 error: 9.94429763581965e-07
# CPU Time: 0.67892 s
#
#
# CONFIG: r = 0, slab_size = 0.015625, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 5184
# L2 error: 1.0032918280307526e-06
# CPU Time: 0.71206 s
#
#
# CONFIG: r = 0, slab_size = 0.015625, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 10304
# L2 error: 1.0055243698491888e-06
# CPU Time: 0.7207 s
#
#
# CONFIG: r = 0, slab_size = 0.015625, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 20544
# L2 error: 1.0060835726332295e-06
# CPU Time: 0.78732 s
#
#
# CONFIG: r = 1, slab_size = 0.5, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 44
# L2 error: 0.0005646945284975485
# CPU Time: 0.0731 s
#
#
# CONFIG: r = 1, slab_size = 0.5, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 84
# L2 error: 0.0005757750314714854
# CPU Time: 0.05952 s
#
#
# CONFIG: r = 1, slab_size = 0.5, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 164
# L2 error: 0.000578589993849436
# CPU Time: 0.05755 s
#
#
# CONFIG: r = 1, slab_size = 0.5, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 324
# L2 error: 0.000579296567913806
# CPU Time: 0.06116 s
#
#
# CONFIG: r = 1, slab_size = 0.5, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 644
# L2 error: 0.0005794733890190251
# CPU Time: 0.0781 s
#
#
# CONFIG: r = 1, slab_size = 0.5, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1284
# L2 error: 0.0005795176053946683
# CPU Time: 0.06367 s
#
#
# CONFIG: r = 1, slab_size = 0.25, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 88
# L2 error: 0.00021872118527299747
# CPU Time: 0.11519 s
#
#
# CONFIG: r = 1, slab_size = 0.25, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 168
# L2 error: 0.00022295206273118887
# CPU Time: 0.12348 s
#
#
# CONFIG: r = 1, slab_size = 0.25, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 328
# L2 error: 0.00022403136147478936
# CPU Time: 0.11459 s
#
#
# CONFIG: r = 1, slab_size = 0.25, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 648
# L2 error: 0.00022430255912895636
# CPU Time: 0.12557 s
#
#
# CONFIG: r = 1, slab_size = 0.25, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1288
# L2 error: 0.0002243704447399888
# CPU Time: 0.11897 s
#
#
# CONFIG: r = 1, slab_size = 0.25, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.25) ...
# Done.
#
# Solving on slab_1 = Ω x (0.25, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2568
# L2 error: 0.0002243874215343413
# CPU Time: 0.13446 s
#
#
# CONFIG: r = 1, slab_size = 0.125, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 176
# L2 error: 6.440509707204759e-05
# CPU Time: 0.23655 s
#
#
# CONFIG: r = 1, slab_size = 0.125, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 336
# L2 error: 6.586419655635946e-05
# CPU Time: 0.25376 s
#
#
# CONFIG: r = 1, slab_size = 0.125, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 656
# L2 error: 6.624048366651269e-05
# CPU Time: 0.25407 s
#
#
# CONFIG: r = 1, slab_size = 0.125, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1296
# L2 error: 6.633529549942942e-05
# CPU Time: 0.23932 s
#
#
# CONFIG: r = 1, slab_size = 0.125, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2576
# L2 error: 6.635904503960856e-05
# CPU Time: 0.3083 s
#
#
# CONFIG: r = 1, slab_size = 0.125, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.125, 0.25) ...
# Done.
#
# Solving on slab_2 = Ω x (0.25, 0.375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 5136
# L2 error: 6.636498534215722e-05
# CPU Time: 0.26008 s
#
#
# CONFIG: r = 1, slab_size = 0.0625, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 352
# L2 error: 1.696470048357132e-05
# CPU Time: 0.47301 s
#
#
# CONFIG: r = 1, slab_size = 0.0625, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 672
# L2 error: 1.7495119146928215e-05
# CPU Time: 0.50503 s
#
#
# CONFIG: r = 1, slab_size = 0.0625, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1312
# L2 error: 1.763458872823819e-05
# CPU Time: 0.4766 s
#
#
# CONFIG: r = 1, slab_size = 0.0625, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2592
# L2 error: 1.766990348488648e-05
# CPU Time: 0.48467 s
#
#
# CONFIG: r = 1, slab_size = 0.0625, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 5152
# L2 error: 1.767876042707945e-05
# CPU Time: 0.52571 s
#
#
# CONFIG: r = 1, slab_size = 0.0625, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.0625) ...
# Done.
#
# Solving on slab_1 = Ω x (0.0625, 0.125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.125, 0.1875) ...
# Done.
#
# Solving on slab_3 = Ω x (0.1875, 0.25) ...
# Done.
#
# Solving on slab_4 = Ω x (0.25, 0.3125) ...
# Done.
#
# Solving on slab_5 = Ω x (0.3125, 0.375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.375, 0.4375) ...
# Done.
#
# Solving on slab_7 = Ω x (0.4375, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 10272
# L2 error: 1.7680976434197122e-05
# CPU Time: 0.51555 s
#
#
# CONFIG: r = 1, slab_size = 0.03125, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 704
# L2 error: 4.252577330728759e-06
# CPU Time: 0.96941 s
#
#
# CONFIG: r = 1, slab_size = 0.03125, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1344
# L2 error: 4.460360573701128e-06
# CPU Time: 0.9918 s
#
#
# CONFIG: r = 1, slab_size = 0.03125, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2624
# L2 error: 4.5169002827575616e-06
# CPU Time: 0.98423 s
#
#
# CONFIG: r = 1, slab_size = 0.03125, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 5184
# L2 error: 4.531339389219035e-06
# CPU Time: 0.96868 s
#
#
# CONFIG: r = 1, slab_size = 0.03125, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 10304
# L2 error: 4.534968450618814e-06
# CPU Time: 1.02466 s
#
#
# CONFIG: r = 1, slab_size = 0.03125, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.03125) ...
# Done.
#
# Solving on slab_1 = Ω x (0.03125, 0.0625) ...
# Done.
#
# Solving on slab_2 = Ω x (0.0625, 0.09375) ...
# Done.
#
# Solving on slab_3 = Ω x (0.09375, 0.125) ...
# Done.
#
# Solving on slab_4 = Ω x (0.125, 0.15625) ...
# Done.
#
# Solving on slab_5 = Ω x (0.15625, 0.1875) ...
# Done.
#
# Solving on slab_6 = Ω x (0.1875, 0.21875) ...
# Done.
#
# Solving on slab_7 = Ω x (0.21875, 0.25) ...
# Done.
#
# Solving on slab_8 = Ω x (0.25, 0.28125) ...
# Done.
#
# Solving on slab_9 = Ω x (0.28125, 0.3125) ...
# Done.
#
# Solving on slab_10 = Ω x (0.3125, 0.34375) ...
# Done.
#
# Solving on slab_11 = Ω x (0.34375, 0.375) ...
# Done.
#
# Solving on slab_12 = Ω x (0.375, 0.40625) ...
# Done.
#
# Solving on slab_13 = Ω x (0.40625, 0.4375) ...
# Done.
#
# Solving on slab_14 = Ω x (0.4375, 0.46875) ...
# Done.
#
# Solving on slab_15 = Ω x (0.46875, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 20544
# L2 error: 4.535876925457942e-06
# CPU Time: 1.09035 s
#
#
# CONFIG: r = 1, slab_size = 0.015625, n_x = 10
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 1408
# L2 error: 1.029481907826011e-06
# CPU Time: 1.95695 s
#
#
# CONFIG: r = 1, slab_size = 0.015625, n_x = 20
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 2688
# L2 error: 1.1139048320838419e-06
# CPU Time: 2.21114 s
#
#
# CONFIG: r = 1, slab_size = 0.015625, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 5248
# L2 error: 1.1384756044323548e-06
# CPU Time: 2.00145 s
#
#
# CONFIG: r = 1, slab_size = 0.015625, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 10368
# L2 error: 1.1448512665589465e-06
# CPU Time: 2.51686 s
#
#
# CONFIG: r = 1, slab_size = 0.015625, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 4032
# L2 error: 1.0437927296264317e-06
# CPU Time: 7.6955 s
#
#
# CONFIG: r = 2, slab_size = 0.015625, n_x = 40
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 7872
# L2 error: 1.0639179289370788e-06
# CPU Time: 7.93994 s
#
#
# CONFIG: r = 2, slab_size = 0.015625, n_x = 80
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 15552
# L2 error: 1.069168026686589e-06
# CPU Time: 8.14084 s
#
#
# CONFIG: r = 2, slab_size = 0.015625, n_x = 160
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 30912
# L2 error: 1.0704944876143214e-06
# CPU Time: 8.73234 s
#
#
# CONFIG: r = 2, slab_size = 0.015625, n_x = 320
# Solving on slab_0 = Ω x (0.0, 0.01562) ...
# Done.
#
# Solving on slab_1 = Ω x (0.01562, 0.03125) ...
# Done.
#
# Solving on slab_2 = Ω x (0.03125, 0.04688) ...
# Done.
#
# Solving on slab_3 = Ω x (0.04688, 0.0625) ...
# Done.
#
# Solving on slab_4 = Ω x (0.0625, 0.07812) ...
# Done.
#
# Solving on slab_5 = Ω x (0.07812, 0.09375) ...
# Done.
#
# Solving on slab_6 = Ω x (0.09375, 0.10938) ...
# Done.
#
# Solving on slab_7 = Ω x (0.10938, 0.125) ...
# Done.
#
# Solving on slab_8 = Ω x (0.125, 0.14062) ...
# Done.
#
# Solving on slab_9 = Ω x (0.14062, 0.15625) ...
# Done.
#
# Solving on slab_10 = Ω x (0.15625, 0.17188) ...
# Done.
#
# Solving on slab_11 = Ω x (0.17188, 0.1875) ...
# Done.
#
# Solving on slab_12 = Ω x (0.1875, 0.20312) ...
# Done.
#
# Solving on slab_13 = Ω x (0.20312, 0.21875) ...
# Done.
#
# Solving on slab_14 = Ω x (0.21875, 0.23438) ...
# Done.
#
# Solving on slab_15 = Ω x (0.23438, 0.25) ...
# Done.
#
# Solving on slab_16 = Ω x (0.25, 0.26562) ...
# Done.
#
# Solving on slab_17 = Ω x (0.26562, 0.28125) ...
# Done.
#
# Solving on slab_18 = Ω x (0.28125, 0.29688) ...
# Done.
#
# Solving on slab_19 = Ω x (0.29688, 0.3125) ...
# Done.
#
# Solving on slab_20 = Ω x (0.3125, 0.32812) ...
# Done.
#
# Solving on slab_21 = Ω x (0.32812, 0.34375) ...
# Done.
#
# Solving on slab_22 = Ω x (0.34375, 0.35938) ...
# Done.
#
# Solving on slab_23 = Ω x (0.35938, 0.375) ...
# Done.
#
# Solving on slab_24 = Ω x (0.375, 0.39062) ...
# Done.
#
# Solving on slab_25 = Ω x (0.39062, 0.40625) ...
# Done.
#
# Solving on slab_26 = Ω x (0.40625, 0.42188) ...
# Done.
#
# Solving on slab_27 = Ω x (0.42188, 0.4375) ...
# Done.
#
# Solving on slab_28 = Ω x (0.4375, 0.45312) ...
# Done.
#
# Solving on slab_29 = Ω x (0.45312, 0.46875) ...
# Done.
#
# Solving on slab_30 = Ω x (0.46875, 0.48438) ...
# Done.
#
# Solving on slab_31 = Ω x (0.48438, 0.5) ...
# Done.
#
# ------------
# | RESULTS: |
# ------------
# Space-time Dofs: 61632
# L2 error: 1.070826977973329e-06
# CPU Time: 5.42694 s
#
#
#
#
# Time for creating convergence table: 250.36201 s
# Convergence table:
# r = 0, s = 1: {(11, 2): {'dofs': 22, 'error': 0.00033390655636383903, 'time': 0.8206}, (21, 2): {'dofs': 42, 'error': 0.0003409845481767041, 'time': 0.02575}, (41, 2): {'dofs': 82, 'error': 0.0003428039419131531, 'time': 0.01824}, (81, 2): {'dofs': 162, 'error': 0.0003432619462392867, 'time': 0.01997}, (161, 2): {'dofs': 322, 'error': 0.0003433766451531571, 'time': 0.0205}, (321, 2): {'dofs': 642, 'error': 0.0003434053322668758, 'time': 0.02141}, (11, 4): {'dofs': 44, 'error': 0.00013769555287012966, 'time': 0.81223}, (21, 4): {'dofs': 84, 'error': 0.00014112438411104913, 'time': 0.03677}, (41, 4): {'dofs': 164, 'error': 0.00014200987472015104, 'time': 0.03596}, (81, 4): {'dofs': 324, 'error': 0.0001422330422988204, 'time': 0.03698}, (161, 4): {'dofs': 644, 'error': 0.00014228894681263363, 'time': 0.04055}, (321, 4): {'dofs': 1284, 'error': 0.00014230292996410916, 'time': 0.04036}, (11, 8): {'dofs': 88, 'error': 4.5500780357867194e-05, 'time': 0.0731}, (21, 8): {'dofs': 168, 'error': 4.697159860075206e-05, 'time': 0.08292}, (41, 8): {'dofs': 328, 'error': 4.7354895906895804e-05, 'time': 0.07384}, (81, 8): {'dofs': 648, 'error': 4.7451716467778596e-05, 'time': 0.07134}, (161, 8): {'dofs': 1288, 'error': 4.7475984221840064e-05, 'time': 0.07825}, (321, 8): {'dofs': 2568, 'error': 4.748205507575802e-05, 'time': 0.08703}, (11, 16): {'dofs': 176, 'error': 1.3166249344691164e-05, 'time': 0.14008}, (21, 16): {'dofs': 336, 'error': 1.379242992442329e-05, 'time': 0.16539}, (41, 16): {'dofs': 656, 'error': 1.3958002037805872e-05, 'time': 0.17141}, (81, 16): {'dofs': 1296, 'error': 1.3999978037426572e-05, 'time': 0.14107}, (161, 16): {'dofs': 2576, 'error': 1.4010508772651705e-05, 'time': 0.15418}, (321, 16): {'dofs': 5136, 'error': 1.4013143760363671e-05, 'time': 0.16373}, (11, 32): {'dofs': 352, 'error': 3.463580623903075e-06, 'time': 0.27905}, (21, 32): {'dofs': 672, 'error': 3.737517416771923e-06, 'time': 0.28315}, (41, 32): {'dofs': 1312, 'error': 3.811704144555984e-06, 'time': 0.27779}, (81, 32): {'dofs': 2592, 'error': 3.830624514753964e-06, 'time': 0.29935}, (161, 32): {'dofs': 5152, 'error': 3.835378239020071e-06, 'time': 0.29952}, (321, 32): {'dofs': 10272, 'error': 3.836568155209206e-06, 'time': 0.32482}, (11, 64): {'dofs': 704, 'error': 8.386581900102804e-07, 'time': 0.56513}, (21, 64): {'dofs': 1344, 'error': 9.600541851731846e-07, 'time': 0.69983}, (41, 64): {'dofs': 2624, 'error': 9.94429763581965e-07, 'time': 0.67892}, (81, 64): {'dofs': 5184, 'error': 1.0032918280307526e-06, 'time': 0.71206}, (161, 64): {'dofs': 10304, 'error': 1.0055243698491888e-06, 'time': 0.7207}, (321, 64): {'dofs': 20544, 'error': 1.0060835726332295e-06, 'time': 0.78732}}
# r = 1, s = 1: {(11, 4): {'dofs': 44, 'error': 0.0005646945284975485, 'time': 0.0731}, (21, 4): {'dofs': 84, 'error': 0.0005757750314714854, 'time': 0.05952}, (41, 4): {'dofs': 164, 'error': 0.000578589993849436, 'time': 0.05755}, (81, 4): {'dofs': 324, 'error': 0.000579296567913806, 'time': 0.06116}, (161, 4): {'dofs': 644, 'error': 0.0005794733890190251, 'time': 0.0781}, (321, 4): {'dofs': 1284, 'error': 0.0005795176053946683, 'time': 0.06367}, (11, 8): {'dofs': 88, 'error': 0.00021872118527299747, 'time': 0.11519}, (21, 8): {'dofs': 168, 'error': 0.00022295206273118887, 'time': 0.12348}, (41, 8): {'dofs': 328, 'error': 0.00022403136147478936, 'time': 0.11459}, (81, 8): {'dofs': 648, 'error': 0.00022430255912895636, 'time': 0.12557}, (161, 8): {'dofs': 1288, 'error': 0.0002243704447399888, 'time': 0.11897}, (321, 8): {'dofs': 2568, 'error': 0.0002243874215343413, 'time': 0.13446}, (11, 16): {'dofs': 176, 'error': 6.440509707204759e-05, 'time': 0.23655}, (21, 16): {'dofs': 336, 'error': 6.586419655635946e-05, 'time': 0.25376}, (41, 16): {'dofs': 656, 'error': 6.624048366651269e-05, 'time': 0.25407}, (81, 16): {'dofs': 1296, 'error': 6.633529549942942e-05, 'time': 0.23932}, (161, 16): {'dofs': 2576, 'error': 6.635904503960856e-05, 'time': 0.3083}, (321, 16): {'dofs': 5136, 'error': 6.636498534215722e-05, 'time': 0.26008}, (11, 32): {'dofs': 352, 'error': 1.696470048357132e-05, 'time': 0.47301}, (21, 32): {'dofs': 672, 'error': 1.7495119146928215e-05, 'time': 0.50503}, (41, 32): {'dofs': 1312, 'error': 1.763458872823819e-05, 'time': 0.4766}, (81, 32): {'dofs': 2592, 'error': 1.766990348488648e-05, 'time': 0.48467}, (161, 32): {'dofs': 5152, 'error': 1.767876042707945e-05, 'time': 0.52571}, (321, 32): {'dofs': 10272, 'error': 1.7680976434197122e-05, 'time': 0.51555}, (11, 64): {'dofs': 704, 'error': 4.252577330728759e-06, 'time': 0.96941}, (21, 64): {'dofs': 1344, 'error': 4.460360573701128e-06, 'time': 0.9918}, (41, 64): {'dofs': 2624, 'error': 4.5169002827575616e-06, 'time': 0.98423}, (81, 64): {'dofs': 5184, 'error': 4.531339389219035e-06, 'time': 0.96868}, (161, 64): {'dofs': 10304, 'error': 4.534968450618814e-06, 'time': 1.02466}, (321, 64): {'dofs': 20544, 'error': 4.535876925457942e-06, 'time': 1.09035}, (11, 128): {'dofs': 1408, 'error': 1.029481907826011e-06, 'time': 1.95695}, (21, 128): {'dofs': 2688, 'error': 1.1139048320838419e-06, 'time': 2.21114}, (41, 128): {'dofs': 5248, 'error': 1.1384756044323548e-06, 'time': 2.00145}, (81, 128): {'dofs': 10368, 'error': 1.1448512665589465e-06, 'time': 2.51686}, (161, 128): {'dofs': 20608, 'error': 1.1464600058985497e-06, 'time': 6.52924}, (321, 128): {'dofs': 41088, 'error': 1.1468631212063916e-06, 'time': 1.80462}}
# r = 2, s = 1: {(11, 6): {'dofs': 66, 'error': 0.0006096756270754226, 'time': 8.3708}, (21, 6): {'dofs': 126, 'error': 0.0006208100413959115, 'time': 0.19636}, (41, 6): {'dofs': 246, 'error': 0.0006236325918963249, 'time': 0.22243}, (81, 6): {'dofs': 486, 'error': 0.0006243406917833525, 'time': 0.24589}, (161, 6): {'dofs': 966, 'error': 0.0006245178710923329, 'time': 0.28763}, (321, 6): {'dofs': 1926, 'error': 0.0006245621755694884, 'time': 0.34131}, (11, 12): {'dofs': 132, 'error': 0.00022039808213787385, 'time': 6.58175}, (21, 12): {'dofs': 252, 'error': 0.0002243791110005729, 'time': 0.2353}, (41, 12): {'dofs': 492, 'error': 0.00022539251012576567, 'time': 0.31784}, (81, 12): {'dofs': 972, 'error': 0.0002256470165040795, 'time': 0.28775}, (161, 12): {'dofs': 1932, 'error': 0.0002257107157487657, 'time': 0.34057}, (321, 12): {'dofs': 3852, 'error': 0.00022572664510413573, 'time': 0.45437}, (11, 24): {'dofs': 264, 'error': 6.26318637600792e-05, 'time': 13.75491}, (21, 24): {'dofs': 504, 'error': 6.393940855566795e-05, 'time': 0.47193}, (41, 24): {'dofs': 984, 'error': 6.427604257051126e-05, 'time': 0.61969}, (81, 24): {'dofs': 1944, 'error': 6.43608300564561e-05, 'time': 0.88813}, (161, 24): {'dofs': 3864, 'error': 6.438206655516e-05, 'time': 2.88606}, (321, 24): {'dofs': 7704, 'error': 6.438737816153328e-05, 'time': 0.69254}, (11, 48): {'dofs': 528, 'error': 1.6181740937873657e-05, 'time': 23.51683}, (21, 48): {'dofs': 1008, 'error': 1.663855610944208e-05, 'time': 0.97211}, (41, 48): {'dofs': 1968, 'error': 1.6758733510441498e-05, 'time': 1.03441}, (81, 48): {'dofs': 3888, 'error': 1.6789169103037635e-05, 'time': 2.52226}, (161, 48): {'dofs': 7728, 'error': 1.6796802740559703e-05, 'time': 2.47021}, (321, 48): {'dofs': 15408, 'error': 1.6798712700758284e-05, 'time': 1.03036}, (11, 96): {'dofs': 1056, 'error': 4.024489694671184e-06, 'time': 41.04103}, (21, 96): {'dofs': 2016, 'error': 4.197278182057393e-06, 'time': 1.93403}, (41, 96): {'dofs': 3936, 'error': 4.24462074377133e-06, 'time': 4.18894}, (81, 96): {'dofs': 7776, 'error': 4.256732324779356e-06, 'time': 4.52832}, (161, 96): {'dofs': 15456, 'error': 4.2597777366131045e-06, 'time': 2.11382}, (321, 96): {'dofs': 30816, 'error': 4.260540188525467e-06, 'time': 6.06267}, (11, 192): {'dofs': 2112, 'error': 9.762519277118396e-07, 'time': 45.84674}, (21, 192): {'dofs': 4032, 'error': 1.0437927296264317e-06, 'time': 7.6955}, (41, 192): {'dofs': 7872, 'error': 1.0639179289370788e-06, 'time': 7.93994}, (81, 192): {'dofs': 15552, 'error': 1.069168026686589e-06, 'time': 8.14084}, (161, 192): {'dofs': 30912, 'error': 1.0704944876143214e-06, 'time': 8.73234}, (321, 192): {'dofs': 61632, 'error': 1.070826977973329e-06, 'time': 5.42694}}

# %%
# TODO: use this later for adaptive mesh refinement
plt.rcParams["figure.figsize"] = [15,15]
plot(U.leaf_node().ufl_function_space().mesh())
plt.show()
